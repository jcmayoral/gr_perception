# %% [markdown]
# # tutorial https://pytorch.org/tutorials/intermediate/torchvision_tutorial.html
#
# ## Note to Jose
# Working version but not fully understood yet
# The next commented think can allow to remove stuff

# %%
# Download TorchVision repo to use some files from
# references/detection
# !git clone git@github.com:jcmayoral/PyTorch-YOLOv3.git yolov3
# Out:
# fatal: destination path 'yolov3' already exists and is not an empty directory.

# %%
from yolov3.models import Darknet

#model_4classes = Darknet(config_path="yolov3/config/yolov3-custom.cfg")

# %%
#nparams = sum(p.numel() for p in model_4classes.parameters())
#print (f"{nparams:,}")

# %%
# !ls
# !pwd
# Out:
#  __pycache__			   pointclouds-deeplearning.ipynb
# 'attempt yolo-binary.ipynb'	   pointnet.ipynb
# 'attempt yolo.ipynb'		   pypcd_hack
#  checkpoints			   rcnntutorial.ipynb
#  coco_eval.py			   runs
#  coco_utils.py			   svmpersons.ipynb
#  decisiontreepersons.ipynb	   testimageyolo.jpg
#  engine.py			   testingyolo
#  iros2021			   testingyolo2
#  iros2021.ipynb			   transforms.py
#  iros2021_depthversion.ipynb	   utils.py
#  linearregressionpersons.ipynb	   vision
#  logisticregressionpersons.ipynb   yolov3
#  output
# /home/jose/ros_ws/src/gr_perception/gr_ml/nb

# %%
bs = 16
nepochs = 50
ncpu = 6
gradient_accumulations = 2
evaluation_interval = 10
checkpoint_interval = 10
img_size = 416

# %%
from __future__ import division

from yolov3.models import *
from yolov3.utils.logger import *
from yolov3.utils.utils import *
from yolov3.utils.datasets import *
from yolov3.utils.parse_config import *
from yolov3.test import evaluate

from terminaltables import AsciiTable

import os
import sys
import time
import datetime
import argparse

import torch
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision import transforms
from torch.autograd import Variable
import torch.optim as optim


"""
parser.add_argument("--epochs", type=int, default=100, help="number of epochs")
parser.add_argument("--batch_size", type=int, default=8, help="size of each image batch")
parser.add_argument("--gradient_accumulations", type=int, default=2, help="number of gradient accums before step")
parser.add_argument("--model_def", type=str, default="config/yolov3.cfg", help="path to model definition file")
parser.add_argument("--data_config", type=str, default="config/coco.data", help="path to data config file")
parser.add_argument("--pretrained_weights", type=str, help="if specified starts from checkpoint model")
parser.add_argument("--n_cpu", type=int, default=8, help="number of cpu threads to use during batch generation")
parser.add_argument("--img_size", type=int, default=416, help="size of each image dimension")
parser.add_argument("--checkpoint_interval", type=int, default=1, help="interval between saving model weights")
parser.add_argument("--evaluation_interval", type=int, default=1, help="interval evaluations on validation set")
parser.add_argument("--compute_map", default=False, help="if True computes mAP every tenth batch")
parser.add_argument("--multiscale_training", default=True, help="allow for multi-scale training")
opt = parser.parse_args()
print(opt)
"""
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

os.makedirs("output", exist_ok=True)
os.makedirs("checkpoints", exist_ok=True)

# Get data configuration
data_config = parse_data_config("yolov3/config/iros2021.data")
#data_config = { line.split()[0] : line.split()[1] for line in open("yolov3/config/jose.data") }

#parse_data_config(opt.data_config)bb
train_path = data_config["train"]
valid_path = data_config["valid"]
class_names = load_classes(data_config["names"])

print(class_names)

# Initiate model
model = Darknet("yolov3/config/iros2021-tiny.cfg").to(device)#, img_size=img_size).to(device)
model.apply(weights_init_normal)

# If specified we start from checkpoint
# Out:
# /home/jose/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/jose/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/jose/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/jose/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/jose/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/jose/.local/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# ['ring0', 'ring1', 'ring2', 'ring3']
# Darknet(
#   (module_list): ModuleList(
#     (0): Sequential(
#       (conv_0): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_0): BatchNorm2d(16, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_0): LeakyReLU(negative_slope=0.1)
#     )
#     (1): Sequential(
#       (maxpool_1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (2): Sequential(
#       (conv_2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_2): BatchNorm2d(32, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_2): LeakyReLU(negative_slope=0.1)
#     )
#     (3): Sequential(
#       (maxpool_3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (4): Sequential(
#       (conv_4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_4): BatchNorm2d(64, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_4): LeakyReLU(negative_slope=0.1)
#     )
#     (5): Sequential(
#       (maxpool_5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (6): Sequential(
#       (conv_6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_6): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_6): LeakyReLU(negative_slope=0.1)
#     )
#     (7): Sequential(
#       (maxpool_7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (8): Sequential(
#       (conv_8): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_8): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_8): LeakyReLU(negative_slope=0.1)
#     )
#     (9): Sequential(
#       (maxpool_9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     )
#     (10): Sequential(
#       (conv_10): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_10): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_10): LeakyReLU(negative_slope=0.1)
#     )
#     (11): Sequential(
#       (_debug_padding_11): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       (maxpool_11): MaxPool2d(kernel_size=2, stride=1, padding=0, dilation=1, ceil_mode=False)
#     )
#     (12): Sequential(
#       (conv_12): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_12): BatchNorm2d(1024, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_12): LeakyReLU(negative_slope=0.1)
#     )
#     (13): Sequential(
#       (conv_13): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_13): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_13): LeakyReLU(negative_slope=0.1)
#     )
#     (14): Sequential(
#       (conv_14): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_14): BatchNorm2d(512, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_14): LeakyReLU(negative_slope=0.1)
#     )
#     (15): Sequential(
#       (conv_15): Conv2d(512, 255, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (16): Sequential(
#       (yolo_16): YOLOLayer(
#         (mse_loss): MSELoss()
#         (bce_loss): BCELoss()
#       )
#     )
#     (17): Sequential(
#       (route_17): EmptyLayer()
#     )
#     (18): Sequential(
#       (conv_18): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (batch_norm_18): BatchNorm2d(128, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_18): LeakyReLU(negative_slope=0.1)
#     )
#     (19): Sequential(
#       (upsample_19): Upsample()
#     )
#     (20): Sequential(
#       (route_20): EmptyLayer()
#     )
#     (21): Sequential(
#       (conv_21): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (batch_norm_21): BatchNorm2d(256, eps=1e-05, momentum=0.9, affine=True, track_running_stats=True)
#       (leaky_21): LeakyReLU(negative_slope=0.1)
#     )
#     (22): Sequential(
#       (conv_22): Conv2d(256, 255, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (23): Sequential(
#       (yolo_23): YOLOLayer(
#         (mse_loss): MSELoss()
#         (bce_loss): BCELoss()
#       )
#     )
#   )
# )

# %%
#model.load_state_dict(torch.load("/home/jose/ros_ws/src/gr_perception/gr_ml/nb/testingyolo/checkpoints/yolov3_v2_ckpt_140.pth"))

# %%
from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter('runs/yolo_rgb')
plot_interval = 100

# %%
# Get dataloader
#For some reason augment or multiscale fails
dataset = ListDataset(train_path, augment=True, multiscale=True)
dataloader = torch.utils.data.DataLoader(
    dataset,
    batch_size=bs,
    shuffle=True,
    num_workers=ncpu,
    pin_memory=False,
    collate_fn=dataset.collate_fn,
)

optimizer = torch.optim.Adam(model.parameters())

metrics = [
    "grid_size",
    "loss",
    "x",
    "y",
    "w",
    "h",
    "conf",
    "cls",
    "cls_acc",
    "recall50",
    "recall75",
    "precision",
    "conf_obj",
    "conf_noobj",
]

try:
    os.makedirs("testingyolo2")
except:
    pass

#logger = Logger("testingyolo/logs")


for epoch in range(nepochs):
    model.train()
    start_time = time.time()
    epoch_loss = 0.0

    for batch_i, (_, imgs, targets) in enumerate(dataloader):
        #print(_)0
        batches_done = len(dataloader) * epoch + batch_i

        imgs = Variable(imgs.to(device))
        targets = Variable(targets.to(device), requires_grad=False)

        loss, outputs = model(imgs, targets)
        loss.backward()
        
        epoch_loss += outputs.shape[0] * loss.item()

        writer.add_scalar('Loss/train_batch', loss,(epoch*len(dataloader)+batch_i))

        if batches_done % gradient_accumulations:
            # Accumulates gradient before each step
            optimizer.step()
            optimizer.zero_grad()

        # ----------------
        #   Log progress
        # ----------------
        yololoss = [yolo.metrics["loss"] for yolo in model.yolo_layers]
        for i, yloss in enumerate(yololoss):
            writer.add_scalar('Loss/yolo_loss'+str(i), yloss,(epoch*len(dataloader)+batch_i))
        #writer.add_scalar('Loss/yolo_loss1', yololoss[1],(epoch*len(dataloader)+batch_i))
        #writer.add_scalar('Loss/yolo_loss2', yololoss[2],(epoch*len(dataloader)+batch_i))

        log_str = "\n---- [Epoch %d/%d, Batch %d/%d] ----\n" % (epoch, nepochs, batch_i, len(dataloader))

        metric_table = [["Metrics", *[f"YOLO Layer {i}" for i in range(len(model.yolo_layers))]]]

        if batch_i % plot_interval == 0:
            # Log metrics at each YOLO layer
            for i, metric in enumerate(metrics):
                formats = {m: "%.6f" for m in metrics}
                formats["grid_size"] = "%2d"
                formats["cls_acc"] = "%.2f%%"
                row_metrics = [formats[metric] % yolo.metrics.get(metric, 0) for yolo in model.yolo_layers]
                metric_table += [[metric, *row_metrics]]

                # Tensorboard logging
                """
                tensorboard_log = []
                for j, yolo in enumerate(model.yolo_layers):
                    for name, metric in yolo.metrics.items():
                        if name != "grid_size":
                            tensorboard_log += [(f"{name}_{j+1}", metric)]
                tensorboard_log += [("loss", loss.item())]
                """
                #logger.list_of_scalars_summary(tensorboard_log, batches_done)

            log_str += AsciiTable(metric_table).table
            log_str += f"\nTotal loss {loss.item()}"

            # Determine approximate time left for epoch
            epoch_batches_left = len(dataloader) - (batch_i + 1)
            time_left = datetime.timedelta(seconds=epoch_batches_left * (time.time() - start_time) / (batch_i + 1))
            log_str += f"\n---- ETA {time_left}"

            print(log_str)
            #break

        model.seen += imgs.size(0)
    
    
    writer.add_scalar('Loss/train_epoch', epoch_loss / len(dataloader), epoch)
    #print ("HERE", len(dataloader), epoch_loss)


    if epoch % evaluation_interval == 0:
        print(log_str)
        print("\n---- Evaluating Model ----")
        # Evaluate the model on the validation set
        eval_results = evaluate(
            model,
            path=valid_path,
            iou_thres=0.5,
            conf_thres=0.5,
            nms_thres=0.5,
            img_size=img_size,
            batch_size=1,
        )
        
        if eval_results is not None:
            precision, recall, AP, f1, ap_class = eval_results
            """
            evaluation_metrics = [
                ("val_precision", precision.mean()),
                ("val_recall", recall.mean()),
                ("val_mAP", AP.mean()),
                ("val_f1", f1.mean()),
            ]
            logger.list_of_scalars_summary(evaluation_metrics, epoch)
            """
            # Print class APs and mAP
            ap_table = [["Index", "Class name", "AP"]]
            for i, c in enumerate(ap_class):
                ap_table += [[c, class_names[c], "%.5f" % AP[i]]]
            print(AsciiTable(ap_table).table)
            print(f"---- mAP {AP.mean()}")
            writer.add_scalar('metrics/map_eval', AP.mean(), int(epoch / evaluation_interval))
            writer.add_scalar('metrics/precision', precision.mean(), int(epoch / evaluation_interval))
            writer.add_scalar('metrics/recall', recall.mean(), int(epoch / evaluation_interval))
            writer.add_scalar('metrics/f1', f1.mean(), int(epoch / evaluation_interval))


    if epoch % checkpoint_interval == 0:
        print (log_str)
        torch.save(model.state_dict(), f"testingyolo/checkpoints/yolov3_v2_ckpt_%d.pth" % epoch)
# Out:
# ---- [Epoch 0/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 73.793518    | 75.919792    |
# | x          | 0.097596     | 0.126384     |
# | y          | 0.060810     | 0.211024     |
# | w          | 0.601752     | 0.909861     |
# | h          | 0.452935     | 0.832950     |
# | conf       | 71.786583    | 73.088730    |
# | cls        | 0.793841     | 0.750843     |
# | cls_acc    | 0.00%        | 0.00%        |
# | recall50   | 0.000000     | 0.000000     |
# | recall75   | 0.000000     | 0.000000     |
# | precision  | 0.000000     | 0.000000     |
# | conf_obj   | 0.420391     | 0.578171     |
# | conf_noobj | 0.502835     | 0.512532     |
# +------------+--------------+--------------+
# Total loss 149.71331787109375
# ---- ETA 0:06:51.646956
#
# ---- [Epoch 0/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 1.573162     | 3.450715     |
# | x          | 0.039943     | 0.056519     |
# | y          | 0.035122     | 0.012587     |
# | w          | 0.070373     | 0.025876     |
# | h          | 0.093470     | 0.032321     |
# | conf       | 1.294651     | 3.284600     |
# | cls        | 0.039603     | 0.038812     |
# | cls_acc    | 56.25%       | 87.50%       |
# | recall50   | 0.562500     | 0.687500     |
# | recall75   | 0.062500     | 0.312500     |
# | precision  | 0.500000     | 0.261905     |
# | conf_obj   | 0.749120     | 0.649626     |
# | conf_noobj | 0.008695     | 0.026396     |
# +------------+--------------+--------------+
# Total loss 5.0238776206970215
# ---- ETA 0:00:47.912227
#
# ---- [Epoch 0/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 0.478652     | 1.369473     |
# | x          | 0.026663     | 0.013819     |
# | y          | 0.006646     | 0.004111     |
# | w          | 0.020483     | 0.020355     |
# | h          | 0.009334     | 0.015658     |
# | conf       | 0.398629     | 1.298464     |
# | cls        | 0.016897     | 0.017067     |
# | cls_acc    | 56.25%       | 62.50%       |
# | recall50   | 0.562500     | 0.625000     |
# | recall75   | 0.437500     | 0.562500     |
# | precision  | 0.562500     | 0.178571     |
# | conf_obj   | 0.956769     | 0.835450     |
# | conf_noobj | 0.003527     | 0.010212     |
# +------------+--------------+--------------+
# Total loss 1.8481253385543823
# ---- ETA 0:00:15.435316
# Detecting objects:   0%|          | 0/400 [00:00<?, ?it/s]
# ---- [Epoch 0/50, Batch 249/250] ----
#
#
# ---- Evaluating Model ----
# Detecting objects: 100%|██████████| 400/400 [00:04<00:00, 86.28it/s]
# Computing AP: 100%|██████████| 4/4 [00:00<00:00, 1268.02it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | ring0      | 0.41366 |
# | 1     | ring1      | 0.47263 |
# | 2     | ring2      | 0.54902 |
# | 3     | ring3      | 0.44936 |
# +-------+------------+---------+
# ---- mAP 0.47117039171611963
#
# ---- [Epoch 0/50, Batch 249/250] ----
#
#
# ---- [Epoch 1/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.930894     | 1.282476     |
# | x          | 0.007098     | 0.032119     |
# | y          | 0.008166     | 0.012087     |
# | w          | 0.052156     | 0.082879     |
# | h          | 0.131338     | 0.035561     |
# | conf       | 0.715780     | 1.103481     |
# | cls        | 0.016356     | 0.016349     |
# | cls_acc    | 75.00%       | 81.25%       |
# | recall50   | 0.625000     | 0.812500     |
# | recall75   | 0.187500     | 0.750000     |
# | precision  | 0.357143     | 0.183099     |
# | conf_obj   | 0.856794     | 0.842935     |
# | conf_noobj | 0.004000     | 0.008156     |
# +------------+--------------+--------------+
# Total loss 2.2133700847625732
# ---- ETA 0:05:35.590925
#
# ---- [Epoch 1/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 1.065557     | 1.016063     |
# | x          | 0.004044     | 0.013515     |
# | y          | 0.002502     | 0.013759     |
# | w          | 0.015156     | 0.004189     |
# | h          | 0.020451     | 0.025745     |
# | conf       | 1.003844     | 0.936665     |
# | cls        | 0.019560     | 0.022190     |
# | cls_acc    | 62.50%       | 62.50%       |
# | recall50   | 0.437500     | 0.562500     |
# | recall75   | 0.437500     | 0.562500     |
# | precision  | 0.388889     | 0.225000     |
# | conf_obj   | 0.680018     | 0.794294     |
# | conf_noobj | 0.004349     | 0.005860     |
# +------------+--------------+--------------+
# Total loss 2.0816192626953125
# ---- ETA 0:00:49.003534
#
# ---- [Epoch 1/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 1.251089     | 0.961514     |
# | x          | 0.028955     | 0.047155     |
# | y          | 0.010402     | 0.031092     |
# | w          | 0.102802     | 0.017947     |
# | h          | 0.256796     | 0.006155     |
# | conf       | 0.837737     | 0.850296     |
# | cls        | 0.014397     | 0.008869     |
# | cls_acc    | 94.12%       | 94.12%       |
# | recall50   | 0.823529     | 0.823529     |
# | recall75   | 0.823529     | 0.823529     |
# | precision  | 0.388889     | 0.222222     |
# | conf_obj   | 0.767358     | 0.799323     |
# | conf_noobj | 0.003419     | 0.004323     |
# +------------+--------------+--------------+
# Total loss 2.2126030921936035
# ---- ETA 0:00:16.399788
#
# ---- [Epoch 2/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 0.267495     | 0.610283     |
# | x          | 0.007287     | 0.023775     |
# | y          | 0.007467     | 0.006297     |
# | w          | 0.007740     | 0.022130     |
# | h          | 0.016902     | 0.019579     |
# | conf       | 0.210378     | 0.523896     |
# | cls        | 0.017721     | 0.014606     |
# | cls_acc    | 81.25%       | 75.00%       |
# | recall50   | 0.812500     | 0.750000     |
# | recall75   | 0.750000     | 0.687500     |
# | precision  | 0.722222     | 0.210526     |
# | conf_obj   | 0.966224     | 0.911151     |
# | conf_noobj | 0.001409     | 0.003443     |
# +------------+--------------+--------------+
# Total loss 0.877778172492981
# ---- ETA 0:04:52.587099
#
# ---- [Epoch 2/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 0.884085     | 0.692569     |
# | x          | 0.013426     | 0.038738     |
# | y          | 0.002647     | 0.006409     |
# | w          | 0.009840     | 0.009205     |
# | h          | 0.022865     | 0.008119     |
# | conf       | 0.816460     | 0.616124     |
# | cls        | 0.018846     | 0.013974     |
# | cls_acc    | 68.75%       | 68.75%       |
# | recall50   | 0.562500     | 0.687500     |
# | recall75   | 0.500000     | 0.625000     |
# | precision  | 0.428571     | 0.250000     |
# | conf_obj   | 0.785130     | 0.860375     |
# | conf_noobj | 0.003032     | 0.003489     |
# +------------+--------------+--------------+
# Total loss 1.5766541957855225
# ---- ETA 0:00:47.428786
#
# ---- [Epoch 2/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 1.083548     | 0.840738     |
# | x          | 0.011174     | 0.051544     |
# | y          | 0.002815     | 0.003945     |
# | w          | 0.028332     | 0.012698     |
# | h          | 0.033091     | 0.009322     |
# | conf       | 0.991631     | 0.749906     |
# | cls        | 0.016505     | 0.013323     |
# | cls_acc    | 75.00%       | 75.00%       |
# | recall50   | 0.500000     | 0.562500     |
# | recall75   | 0.500000     | 0.562500     |
# | precision  | 0.363636     | 0.236842     |
# | conf_obj   | 0.681190     | 0.746798     |
# | conf_noobj | 0.002729     | 0.002682     |
# +------------+--------------+--------------+
# Total loss 1.9242860078811646
# ---- ETA 0:00:15.360335
#
# ---- [Epoch 3/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 0.886847     | 0.704384     |
# | x          | 0.005020     | 0.013119     |
# | y          | 0.007013     | 0.012766     |
# | w          | 0.010132     | 0.015139     |
# | h          | 0.007088     | 0.012646     |
# | conf       | 0.836133     | 0.634691     |
# | cls        | 0.021460     | 0.016024     |
# | cls_acc    | 62.50%       | 81.25%       |
# | recall50   | 0.562500     | 0.750000     |
# | recall75   | 0.562500     | 0.750000     |
# | precision  | 0.473684     | 0.333333     |
# | conf_obj   | 0.803204     | 0.870877     |
# | conf_noobj | 0.002238     | 0.002526     |
# +------------+--------------+--------------+
# Total loss 1.591231107711792
# ---- ETA 0:04:20.577423
#
# ---- [Epoch 3/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 0.723306     | 0.487157     |
# | x          | 0.007403     | 0.014831     |
# | y          | 0.000927     | 0.002756     |
# | w          | 0.013608     | 0.015119     |
# | h          | 0.012449     | 0.006390     |
# | conf       | 0.678919     | 0.439526     |
# | cls        | 0.009999     | 0.008536     |
# | cls_acc    | 100.00%      | 87.50%       |
# | recall50   | 0.937500     | 0.875000     |
# | recall75   | 0.812500     | 0.812500     |
# | precision  | 0.483871     | 0.269231     |
# | conf_obj   | 0.842832     | 0.935992     |
# | conf_noobj | 0.003344     | 0.002440     |
# +------------+--------------+--------------+
# Total loss 1.2104625701904297
# ---- ETA 0:00:50.558300
#
# ---- [Epoch 3/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.666896     | 0.565894     |
# | x          | 0.025231     | 0.018390     |
# | y          | 0.009140     | 0.013144     |
# | w          | 0.025282     | 0.009518     |
# | h          | 0.019250     | 0.029047     |
# | conf       | 0.574582     | 0.483515     |
# | cls        | 0.013411     | 0.012280     |
# | cls_acc    | 75.00%       | 75.00%       |
# | recall50   | 0.750000     | 0.625000     |
# | recall75   | 0.500000     | 0.500000     |
# | precision  | 0.387097     | 0.163934     |
# | conf_obj   | 0.814892     | 0.859219     |
# | conf_noobj | 0.002080     | 0.002105     |
# +------------+--------------+--------------+
# Total loss 1.2327897548675537
# ---- ETA 0:00:16.346482
# ---- [Epoch 4/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.814582     | 0.564540     |
# | x          | 0.020839     | 0.025133     |
# | y          | 0.002135     | 0.013427     |
# | w          | 0.057663     | 0.023745     |
# | h          | 0.103925     | 0.008022     |
# | conf       | 0.605773     | 0.484347     |
# | cls        | 0.024247     | 0.009868     |
# | cls_acc    | 43.75%       | 93.75%       |
# | recall50   | 0.375000     | 0.875000     |
# | recall75   | 0.062500     | 0.750000     |
# | precision  | 0.240000     | 0.297872     |
# | conf_obj   | 0.810291     | 0.852947     |
# | conf_noobj | 0.001890     | 0.001794     |
# +------------+--------------+--------------+
# Total loss 1.3791224956512451
# ---- ETA 0:05:12.401705
#
# ---- [Epoch 4/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 0.257966     | 0.392644     |
# | x          | 0.001567     | 0.008787     |
# | y          | 0.012166     | 0.014496     |
# | w          | 0.010533     | 0.007233     |
# | h          | 0.009355     | 0.004698     |
# | conf       | 0.210103     | 0.350010     |
# | cls        | 0.014242     | 0.007419     |
# | cls_acc    | 75.00%       | 93.75%       |
# | recall50   | 0.750000     | 0.937500     |
# | recall75   | 0.750000     | 0.937500     |
# | precision  | 0.600000     | 0.375000     |
# | conf_obj   | 0.959056     | 0.901755     |
# | conf_noobj | 0.001021     | 0.001714     |
# +------------+--------------+--------------+
# Total loss 0.650610089302063
# ---- ETA 0:01:00.837597
#
# ---- [Epoch 4/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.883317     | 0.490984     |
# | x          | 0.007160     | 0.022591     |
# | y          | 0.004620     | 0.004798     |
# | w          | 0.103828     | 0.017031     |
# | h          | 0.179457     | 0.008552     |
# | conf       | 0.577789     | 0.430165     |
# | cls        | 0.010462     | 0.007847     |
# | cls_acc    | 82.35%       | 100.00%      |
# | recall50   | 0.823529     | 0.941176     |
# | recall75   | 0.823529     | 0.823529     |
# | precision  | 0.451613     | 0.307692     |
# | conf_obj   | 0.863003     | 0.882113     |
# | conf_noobj | 0.001610     | 0.001526     |
# +------------+--------------+--------------+
# Total loss 1.3743011951446533
# ---- ETA 0:00:18.321678
#
# ---- [Epoch 5/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 1.338488     | 0.653350     |
# | x          | 0.004613     | 0.005512     |
# | y          | 0.001740     | 0.003844     |
# | w          | 0.032442     | 0.017778     |
# | h          | 0.013455     | 0.011521     |
# | conf       | 1.270476     | 0.594076     |
# | cls        | 0.015761     | 0.020620     |
# | cls_acc    | 62.50%       | 68.75%       |
# | recall50   | 0.312500     | 0.625000     |
# | recall75   | 0.250000     | 0.625000     |
# | precision  | 0.238095     | 0.243902     |
# | conf_obj   | 0.627631     | 0.864422     |
# | conf_noobj | 0.002758     | 0.002316     |
# +------------+--------------+--------------+
# Total loss 1.9918384552001953
# ---- ETA 0:05:14.332651
#
# ---- [Epoch 5/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 0.585448     | 0.543667     |
# | x          | 0.004143     | 0.010219     |
# | y          | 0.005395     | 0.018029     |
# | w          | 0.028208     | 0.010528     |
# | h          | 0.005977     | 0.004580     |
# | conf       | 0.528937     | 0.490185     |
# | cls        | 0.012788     | 0.010125     |
# | cls_acc    | 93.75%       | 93.75%       |
# | recall50   | 0.937500     | 0.875000     |
# | recall75   | 0.937500     | 0.875000     |
# | precision  | 0.555556     | 0.333333     |
# | conf_obj   | 0.837849     | 0.855739     |
# | conf_noobj | 0.002271     | 0.001931     |
# +------------+--------------+--------------+
# Total loss 1.1291149854660034
# ---- ETA 0:00:45.670342
#
# ---- [Epoch 5/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 0.806808     | 0.631962     |
# | x          | 0.009971     | 0.036252     |
# | y          | 0.000948     | 0.013856     |
# | w          | 0.036266     | 0.027452     |
# | h          | 0.011616     | 0.012951     |
# | conf       | 0.739370     | 0.532830     |
# | cls        | 0.008636     | 0.008622     |
# | cls_acc    | 81.25%       | 87.50%       |
# | recall50   | 0.812500     | 0.875000     |
# | recall75   | 0.687500     | 0.812500     |
# | precision  | 0.406250     | 0.264151     |
# | conf_obj   | 0.767510     | 0.820149     |
# | conf_noobj | 0.002155     | 0.001655     |
# +------------+--------------+--------------+
# Total loss 1.4387694597244263
# ---- ETA 0:00:15.904405
#
# ---- [Epoch 6/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 0.809793     | 0.708516     |
# | x          | 0.006870     | 0.015658     |
# | y          | 0.007639     | 0.005339     |
# | w          | 0.022334     | 0.011515     |
# | h          | 0.046051     | 0.007582     |
# | conf       | 0.713364     | 0.650468     |
# | cls        | 0.013535     | 0.017954     |
# | cls_acc    | 75.00%       | 50.00%       |
# | recall50   | 0.625000     | 0.437500     |
# | recall75   | 0.500000     | 0.437500     |
# | precision  | 0.555556     | 0.179487     |
# | conf_obj   | 0.881375     | 0.872991     |
# | conf_noobj | 0.001268     | 0.001622     |
# +------------+--------------+--------------+
# Total loss 1.5183093547821045
# ---- ETA 0:04:09.674935
#
# ---- [Epoch 6/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 1.417585     | 1.316579     |
# | x          | 0.022185     | 0.019934     |
# | y          | 0.056293     | 0.029010     |
# | w          | 0.027441     | 0.007571     |
# | h          | 0.022854     | 0.013698     |
# | conf       | 1.269342     | 1.221538     |
# | cls        | 0.019470     | 0.024828     |
# | cls_acc    | 76.47%       | 76.47%       |
# | recall50   | 0.529412     | 0.470588     |
# | recall75   | 0.529412     | 0.470588     |
# | precision  | 0.310345     | 0.166667     |
# | conf_obj   | 0.701594     | 0.654539     |
# | conf_noobj | 0.002133     | 0.001945     |
# +------------+--------------+--------------+
# Total loss 2.734164237976074
# ---- ETA 0:00:46.000204
#
# ---- [Epoch 6/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 0.564060     | 0.375666     |
# | x          | 0.011618     | 0.021383     |
# | y          | 0.010575     | 0.011782     |
# | w          | 0.012294     | 0.011370     |
# | h          | 0.016991     | 0.003074     |
# | conf       | 0.502998     | 0.319105     |
# | cls        | 0.009583     | 0.008953     |
# | cls_acc    | 81.25%       | 93.75%       |
# | recall50   | 0.812500     | 0.937500     |
# | recall75   | 0.750000     | 0.937500     |
# | precision  | 0.500000     | 0.348837     |
# | conf_obj   | 0.859336     | 0.892288     |
# | conf_noobj | 0.001784     | 0.001286     |
# +------------+--------------+--------------+
# Total loss 0.9397258758544922
# ---- ETA 0:00:15.055373
#
# ---- [Epoch 7/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 0.287581     | 0.515776     |
# | x          | 0.008574     | 0.022175     |
# | y          | 0.009353     | 0.005925     |
# | w          | 0.007910     | 0.011038     |
# | h          | 0.033954     | 0.007890     |
# | conf       | 0.217771     | 0.459092     |
# | cls        | 0.010020     | 0.009657     |
# | cls_acc    | 87.50%       | 81.25%       |
# | recall50   | 0.875000     | 0.687500     |
# | recall75   | 0.875000     | 0.687500     |
# | precision  | 0.608696     | 0.203704     |
# | conf_obj   | 0.946959     | 0.867102     |
# | conf_noobj | 0.000970     | 0.001494     |
# +------------+--------------+--------------+
# Total loss 0.8033571243286133
# ---- ETA 0:05:03.039829
# ---- [Epoch 7/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 0.127216     | 0.300491     |
# | x          | 0.008944     | 0.019134     |
# | y          | 0.001887     | 0.001522     |
# | w          | 0.015345     | 0.008269     |
# | h          | 0.005397     | 0.004893     |
# | conf       | 0.085589     | 0.257607     |
# | cls        | 0.010053     | 0.009065     |
# | cls_acc    | 87.50%       | 81.25%       |
# | recall50   | 0.875000     | 0.812500     |
# | recall75   | 0.875000     | 0.812500     |
# | precision  | 0.823529     | 0.464286     |
# | conf_obj   | 0.981709     | 0.917429     |
# | conf_noobj | 0.000517     | 0.001052     |
# +------------+--------------+--------------+
# Total loss 0.42770737409591675
# ---- ETA 0:00:49.491633
#
# ---- [Epoch 7/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.572690     | 0.444332     |
# | x          | 0.006142     | 0.014947     |
# | y          | 0.000963     | 0.004227     |
# | w          | 0.012560     | 0.008678     |
# | h          | 0.005341     | 0.006435     |
# | conf       | 0.540560     | 0.398440     |
# | cls        | 0.007124     | 0.011605     |
# | cls_acc    | 93.75%       | 87.50%       |
# | recall50   | 0.875000     | 0.812500     |
# | recall75   | 0.875000     | 0.812500     |
# | precision  | 0.424242     | 0.220339     |
# | conf_obj   | 0.836104     | 0.892397     |
# | conf_noobj | 0.001715     | 0.001214     |
# +------------+--------------+--------------+
# Total loss 1.0170222520828247
# ---- ETA 0:00:16.189990
#
# ---- [Epoch 8/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 0.421711     | 0.320708     |
# | x          | 0.008882     | 0.017316     |
# | y          | 0.000826     | 0.002701     |
# | w          | 0.016508     | 0.014875     |
# | h          | 0.006060     | 0.004896     |
# | conf       | 0.379059     | 0.274488     |
# | cls        | 0.010376     | 0.006433     |
# | cls_acc    | 87.50%       | 100.00%      |
# | recall50   | 0.812500     | 0.937500     |
# | recall75   | 0.812500     | 0.937500     |
# | precision  | 0.619048     | 0.468750     |
# | conf_obj   | 0.891034     | 0.914899     |
# | conf_noobj | 0.001255     | 0.001008     |
# +------------+--------------+--------------+
# Total loss 0.7424188256263733
# ---- ETA 0:04:16.577268
#
# ---- [Epoch 8/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 0.540091     | 0.396482     |
# | x          | 0.005175     | 0.008247     |
# | y          | 0.003817     | 0.009800     |
# | w          | 0.008061     | 0.013457     |
# | h          | 0.002617     | 0.008870     |
# | conf       | 0.507948     | 0.343851     |
# | cls        | 0.012474     | 0.012257     |
# | cls_acc    | 75.00%       | 75.00%       |
# | recall50   | 0.750000     | 0.750000     |
# | recall75   | 0.750000     | 0.687500     |
# | precision  | 0.500000     | 0.375000     |
# | conf_obj   | 0.876829     | 0.916567     |
# | conf_noobj | 0.002164     | 0.001453     |
# +------------+--------------+--------------+
# Total loss 0.9365725517272949
# ---- ETA 0:00:46.060279
#
# ---- [Epoch 8/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 0.197522     | 0.329230     |
# | x          | 0.012100     | 0.021627     |
# | y          | 0.004345     | 0.001553     |
# | w          | 0.023972     | 0.013599     |
# | h          | 0.021373     | 0.008091     |
# | conf       | 0.123353     | 0.274071     |
# | cls        | 0.012379     | 0.010289     |
# | cls_acc    | 62.50%       | 62.50%       |
# | recall50   | 0.625000     | 0.625000     |
# | recall75   | 0.562500     | 0.562500     |
# | precision  | 0.555556     | 0.270270     |
# | conf_obj   | 0.961615     | 0.933457     |
# | conf_noobj | 0.000478     | 0.001163     |
# +------------+--------------+--------------+
# Total loss 0.5267519950866699
# ---- ETA 0:00:15.682798
#
# ---- [Epoch 9/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 0.591484     | 0.393049     |
# | x          | 0.006189     | 0.016074     |
# | y          | 0.003115     | 0.003209     |
# | w          | 0.008121     | 0.012318     |
# | h          | 0.008124     | 0.004021     |
# | conf       | 0.554832     | 0.347009     |
# | cls        | 0.011104     | 0.010418     |
# | cls_acc    | 87.50%       | 75.00%       |
# | recall50   | 0.812500     | 0.750000     |
# | recall75   | 0.750000     | 0.687500     |
# | precision  | 0.541667     | 0.272727     |
# | conf_obj   | 0.818355     | 0.952630     |
# | conf_noobj | 0.001732     | 0.001519     |
# +------------+--------------+--------------+
# Total loss 0.9845327138900757
# ---- ETA 0:04:19.791593
#
# ---- [Epoch 9/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 0.379136     | 0.417031     |
# | x          | 0.005711     | 0.008132     |
# | y          | 0.004026     | 0.004734     |
# | w          | 0.018313     | 0.004359     |
# | h          | 0.034496     | 0.002983     |
# | conf       | 0.303620     | 0.383812     |
# | cls        | 0.012969     | 0.013012     |
# | cls_acc    | 62.50%       | 75.00%       |
# | recall50   | 0.562500     | 0.687500     |
# | recall75   | 0.562500     | 0.687500     |
# | precision  | 0.562500     | 0.314286     |
# | conf_obj   | 0.905713     | 0.868755     |
# | conf_noobj | 0.000779     | 0.001198     |
# +------------+--------------+--------------+
# Total loss 0.7961665391921997
# ---- ETA 0:00:55.575123
#
# ---- [Epoch 9/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 0.738462     | 0.314742     |
# | x          | 0.013508     | 0.018230     |
# | y          | 0.005315     | 0.002974     |
# | w          | 0.097487     | 0.012386     |
# | h          | 0.293206     | 0.001914     |
# | conf       | 0.317008     | 0.264784     |
# | cls        | 0.011937     | 0.014454     |
# | cls_acc    | 87.50%       | 64.71%       |
# | recall50   | 0.687500     | 0.588235     |
# | recall75   | 0.687500     | 0.588235     |
# | precision  | 0.611111     | 0.370370     |
# | conf_obj   | 0.885149     | 0.907139     |
# | conf_noobj | 0.001104     | 0.000937     |
# +------------+--------------+--------------+
# Total loss 1.0532035827636719
# ---- ETA 0:00:17.524650
#
# ---- [Epoch 10/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 0.271464     | 0.268059     |
# | x          | 0.002699     | 0.004758     |
# | y          | 0.003365     | 0.004324     |
# | w          | 0.012223     | 0.011191     |
# | h          | 0.005038     | 0.004707     |
# | conf       | 0.241037     | 0.236925     |
# | cls        | 0.007104     | 0.006154     |
# | cls_acc    | 93.75%       | 93.75%       |
# | recall50   | 0.937500     | 0.937500     |
# | recall75   | 0.937500     | 0.937500     |
# | precision  | 0.789474     | 0.441176     |
# | conf_obj   | 0.933727     | 0.963908     |
# | conf_noobj | 0.001125     | 0.001104     |
# +------------+--------------+--------------+
# Total loss 0.5395234823226929
# ---- ETA 0:04:19.971294
#
# ---- [Epoch 10/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 0.213209     | 0.417202     |
# | x          | 0.004134     | 0.011724     |
# | y          | 0.012959     | 0.005544     |
# | w          | 0.022991     | 0.010558     |
# | h          | 0.047797     | 0.007507     |
# | conf       | 0.118173     | 0.373499     |
# | cls        | 0.007156     | 0.008372     |
# | cls_acc    | 87.50%       | 93.75%       |
# | recall50   | 0.875000     | 0.937500     |
# | recall75   | 0.562500     | 0.937500     |
# | precision  | 0.777778     | 0.428571     |
# | conf_obj   | 0.975664     | 0.897825     |
# | conf_noobj | 0.000552     | 0.001409     |
# +------------+--------------+--------------+
# Total loss 0.6304107904434204
# ---- ETA 0:00:48.748517
# ---- [Epoch 10/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 0.482555     | 0.326545     |
# | x          | 0.005583     | 0.006636     |
# | y          | 0.003068     | 0.006508     |
# | w          | 0.006884     | 0.003930     |
# | h          | 0.009870     | 0.004885     |
# | conf       | 0.445265     | 0.294808     |
# | cls        | 0.011886     | 0.009778     |
# | cls_acc    | 68.75%       | 81.25%       |
# | recall50   | 0.625000     | 0.750000     |
# | recall75   | 0.625000     | 0.750000     |
# | precision  | 0.454545     | 0.342857     |
# | conf_obj   | 0.907869     | 0.919233     |
# | conf_noobj | 0.001116     | 0.000934     |
# +------------+--------------+--------------+
# Total loss 0.8091006278991699
# ---- ETA 0:00:16.554785
# Detecting objects:   0%|          | 0/400 [00:00<?, ?it/s]
# ---- [Epoch 10/50, Batch 249/250] ----
#
#
# ---- Evaluating Model ----
# Detecting objects: 100%|██████████| 400/400 [00:04<00:00, 85.87it/s]
# Computing AP: 100%|██████████| 4/4 [00:00<00:00, 3004.52it/s]
# +-------+------------+---------+
# | Index | Class name | AP      |
# +-------+------------+---------+
# | 0     | ring0      | 0.66496 |
# | 1     | ring1      | 0.70145 |
# | 2     | ring2      | 0.82567 |
# | 3     | ring3      | 0.90838 |
# +-------+------------+---------+
# ---- mAP 0.7751154305362655
#
# ---- [Epoch 10/50, Batch 249/250] ----
# ---- [Epoch 11/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 0.238852     | 0.245908     |
# | x          | 0.003169     | 0.006743     |
# | y          | 0.006588     | 0.004801     |
# | w          | 0.014878     | 0.005542     |
# | h          | 0.006249     | 0.003901     |
# | conf       | 0.201990     | 0.217187     |
# | cls        | 0.005978     | 0.007735     |
# | cls_acc    | 93.75%       | 93.75%       |
# | recall50   | 0.937500     | 0.937500     |
# | recall75   | 0.937500     | 0.937500     |
# | precision  | 0.714286     | 0.333333     |
# | conf_obj   | 0.939184     | 0.955269     |
# | conf_noobj | 0.000824     | 0.000947     |
# +------------+--------------+--------------+
# Total loss 0.484760582447052
# ---- ETA 0:05:04.868546
#
# ---- [Epoch 11/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 0.066325     | 0.180717     |
# | x          | 0.005663     | 0.002739     |
# | y          | 0.005039     | 0.002148     |
# | w          | 0.007068     | 0.009261     |
# | h          | 0.003910     | 0.003787     |
# | conf       | 0.038252     | 0.155792     |
# | cls        | 0.006393     | 0.006990     |
# | cls_acc    | 93.75%       | 87.50%       |
# | recall50   | 0.937500     | 0.875000     |
# | recall75   | 0.937500     | 0.875000     |
# | precision  | 0.937500     | 0.451613     |
# | conf_obj   | 0.993122     | 0.978022     |
# | conf_noobj | 0.000280     | 0.000774     |
# +------------+--------------+--------------+
# Total loss 0.24704158306121826
# ---- ETA 0:00:52.251740
#
# ---- [Epoch 11/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 1.154138     | 0.692976     |
# | x          | 0.011912     | 0.017312     |
# | y          | 0.016086     | 0.013662     |
# | w          | 0.201380     | 0.044686     |
# | h          | 0.364946     | 0.029144     |
# | conf       | 0.545697     | 0.576201     |
# | cls        | 0.014118     | 0.011970     |
# | cls_acc    | 82.35%       | 83.33%       |
# | recall50   | 0.705882     | 0.555556     |
# | recall75   | 0.647059     | 0.500000     |
# | precision  | 0.705882     | 0.400000     |
# | conf_obj   | 0.795622     | 0.768675     |
# | conf_noobj | 0.001519     | 0.001413     |
# +------------+--------------+--------------+
# Total loss 1.847114086151123
# ---- ETA 0:00:16.978459
#
# ---- [Epoch 12/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 1.216823     | 0.534948     |
# | x          | 0.008891     | 0.006020     |
# | y          | 0.002806     | 0.001204     |
# | w          | 0.141641     | 0.007161     |
# | h          | 0.260262     | 0.001983     |
# | conf       | 0.796105     | 0.508931     |
# | cls        | 0.007118     | 0.009650     |
# | cls_acc    | 93.75%       | 82.35%       |
# | recall50   | 0.687500     | 0.764706     |
# | recall75   | 0.687500     | 0.764706     |
# | precision  | 0.578947     | 0.406250     |
# | conf_obj   | 0.791340     | 0.836097     |
# | conf_noobj | 0.002128     | 0.001238     |
# +------------+--------------+--------------+
# Total loss 1.7517715692520142
# ---- ETA 0:04:00.343573
#
# ---- [Epoch 12/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 0.747203     | 0.415392     |
# | x          | 0.012214     | 0.003406     |
# | y          | 0.013071     | 0.005833     |
# | w          | 0.254796     | 0.013021     |
# | h          | 0.364461     | 0.010833     |
# | conf       | 0.095353     | 0.373066     |
# | cls        | 0.007309     | 0.009233     |
# | cls_acc    | 93.75%       | 88.24%       |
# | recall50   | 0.875000     | 0.882353     |
# | recall75   | 0.875000     | 0.823529     |
# | precision  | 0.777778     | 0.348837     |
# | conf_obj   | 0.986518     | 0.858459     |
# | conf_noobj | 0.000360     | 0.001074     |
# +------------+--------------+--------------+
# Total loss 1.1625946760177612
# ---- ETA 0:00:43.585380
#
# ---- [Epoch 12/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.250764     | 0.250708     |
# | x          | 0.007946     | 0.017066     |
# | y          | 0.001757     | 0.012068     |
# | w          | 0.011885     | 0.016202     |
# | h          | 0.007126     | 0.012193     |
# | conf       | 0.214252     | 0.184243     |
# | cls        | 0.007797     | 0.008936     |
# | cls_acc    | 87.50%       | 87.50%       |
# | recall50   | 0.875000     | 0.875000     |
# | recall75   | 0.875000     | 0.750000     |
# | precision  | 0.666667     | 0.304348     |
# | conf_obj   | 0.927968     | 0.961529     |
# | conf_noobj | 0.000854     | 0.000855     |
# +------------+--------------+--------------+
# Total loss 0.501471757888794
# ---- ETA 0:00:15.424874
#
# ---- [Epoch 13/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 1.017774     | 0.889054     |
# | x          | 0.004151     | 0.013482     |
# | y          | 0.001108     | 0.013397     |
# | w          | 0.027571     | 0.010062     |
# | h          | 0.006820     | 0.007569     |
# | conf       | 0.961001     | 0.818211     |
# | cls        | 0.017122     | 0.026334     |
# | cls_acc    | 68.75%       | 56.25%       |
# | recall50   | 0.625000     | 0.500000     |
# | recall75   | 0.625000     | 0.500000     |
# | precision  | 0.476190     | 0.275862     |
# | conf_obj   | 0.819492     | 0.865064     |
# | conf_noobj | 0.001664     | 0.001136     |
# +------------+--------------+--------------+
# Total loss 1.9068275690078735
# ---- ETA 0:03:51.222962
#
# ---- [Epoch 13/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 0.593511     | 0.277146     |
# | x          | 0.002095     | 0.002857     |
# | y          | 0.001460     | 0.002714     |
# | w          | 0.016011     | 0.019167     |
# | h          | 0.021238     | 0.011082     |
# | conf       | 0.543265     | 0.230586     |
# | cls        | 0.009443     | 0.010739     |
# | cls_acc    | 87.50%       | 81.25%       |
# | recall50   | 0.812500     | 0.812500     |
# | recall75   | 0.812500     | 0.750000     |
# | precision  | 0.590909     | 0.448276     |
# | conf_obj   | 0.814473     | 0.936483     |
# | conf_noobj | 0.001777     | 0.000964     |
# +------------+--------------+--------------+
# Total loss 0.8706566095352173
# ---- ETA 0:00:45.236190
#
# ---- [Epoch 13/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 0.553544     | 0.291151     |
# | x          | 0.011647     | 0.005654     |
# | y          | 0.001223     | 0.002572     |
# | w          | 0.025478     | 0.008322     |
# | h          | 0.017168     | 0.006090     |
# | conf       | 0.492686     | 0.266683     |
# | cls        | 0.005342     | 0.001831     |
# | cls_acc    | 93.75%       | 100.00%      |
# | recall50   | 0.875000     | 1.000000     |
# | recall75   | 0.812500     | 1.000000     |
# | precision  | 0.560000     | 0.470588     |
# | conf_obj   | 0.859302     | 0.967960     |
# | conf_noobj | 0.002126     | 0.001159     |
# +------------+--------------+--------------+
# Total loss 0.8446947336196899
# ---- ETA 0:00:14.974008
#
# ---- [Epoch 14/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 0.861051     | 0.411750     |
# | x          | 0.012857     | 0.020879     |
# | y          | 0.001113     | 0.008141     |
# | w          | 0.022976     | 0.005646     |
# | h          | 0.035796     | 0.003978     |
# | conf       | 0.776909     | 0.360777     |
# | cls        | 0.011400     | 0.012329     |
# | cls_acc    | 81.25%       | 81.25%       |
# | recall50   | 0.687500     | 0.812500     |
# | recall75   | 0.625000     | 0.812500     |
# | precision  | 0.500000     | 0.371429     |
# | conf_obj   | 0.756704     | 0.898788     |
# | conf_noobj | 0.002233     | 0.001206     |
# +------------+--------------+--------------+
# Total loss 1.2728009223937988
# ---- ETA 0:03:48.245508
# ---- [Epoch 14/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 0.151072     | 0.212668     |
# | x          | 0.006914     | 0.005427     |
# | y          | 0.014256     | 0.005908     |
# | w          | 0.007588     | 0.005055     |
# | h          | 0.004219     | 0.001816     |
# | conf       | 0.106452     | 0.183784     |
# | cls        | 0.011643     | 0.010678     |
# | cls_acc    | 75.00%       | 87.50%       |
# | recall50   | 0.750000     | 0.875000     |
# | recall75   | 0.750000     | 0.875000     |
# | precision  | 0.666667     | 0.424242     |
# | conf_obj   | 0.979477     | 0.956512     |
# | conf_noobj | 0.000624     | 0.000811     |
# +------------+--------------+--------------+
# Total loss 0.36374005675315857
# ---- ETA 0:00:46.813386
#
# ---- [Epoch 14/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.734931     | 0.250791     |
# | x          | 0.008324     | 0.012378     |
# | y          | 0.008150     | 0.006141     |
# | w          | 0.146747     | 0.013395     |
# | h          | 0.329070     | 0.010368     |
# | conf       | 0.232774     | 0.194626     |
# | cls        | 0.009867     | 0.013883     |
# | cls_acc    | 87.50%       | 76.47%       |
# | recall50   | 0.875000     | 0.764706     |
# | recall75   | 0.812500     | 0.705882     |
# | precision  | 0.538462     | 0.317073     |
# | conf_obj   | 0.944770     | 0.942265     |
# | conf_noobj | 0.000994     | 0.000670     |
# +------------+--------------+--------------+
# Total loss 0.9857213497161865
# ---- ETA 0:00:15.486935
#
# ---- [Epoch 15/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 0.394840     | 0.612354     |
# | x          | 0.008995     | 0.003443     |
# | y          | 0.000924     | 0.001958     |
# | w          | 0.020237     | 0.015987     |
# | h          | 0.008096     | 0.008836     |
# | conf       | 0.352660     | 0.577282     |
# | cls        | 0.003928     | 0.004848     |
# | cls_acc    | 100.00%      | 100.00%      |
# | recall50   | 1.000000     | 0.875000     |
# | recall75   | 1.000000     | 0.875000     |
# | precision  | 0.666667     | 0.358974     |
# | conf_obj   | 0.910282     | 0.833588     |
# | conf_noobj | 0.001139     | 0.000944     |
# +------------+--------------+--------------+
# Total loss 1.0071938037872314
# ---- ETA 0:04:43.603683
#
# ---- [Epoch 15/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 1.160896     | 0.464904     |
# | x          | 0.019272     | 0.015326     |
# | y          | 0.010226     | 0.019869     |
# | w          | 0.151983     | 0.012368     |
# | h          | 0.309434     | 0.013966     |
# | conf       | 0.655041     | 0.390305     |
# | cls        | 0.014939     | 0.013071     |
# | cls_acc    | 82.35%       | 83.33%       |
# | recall50   | 0.647059     | 0.722222     |
# | recall75   | 0.647059     | 0.666667     |
# | precision  | 0.423077     | 0.265306     |
# | conf_obj   | 0.769218     | 0.886968     |
# | conf_noobj | 0.001455     | 0.001267     |
# +------------+--------------+--------------+
# Total loss 1.6258007287979126
# ---- ETA 0:00:56.717715
#
# ---- [Epoch 15/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.508172     | 0.371007     |
# | x          | 0.004864     | 0.010976     |
# | y          | 0.010257     | 0.006637     |
# | w          | 0.016366     | 0.022008     |
# | h          | 0.003993     | 0.006586     |
# | conf       | 0.461898     | 0.310244     |
# | cls        | 0.010794     | 0.014556     |
# | cls_acc    | 87.50%       | 81.25%       |
# | recall50   | 0.875000     | 0.812500     |
# | recall75   | 0.812500     | 0.750000     |
# | precision  | 0.437500     | 0.276596     |
# | conf_obj   | 0.871869     | 0.889662     |
# | conf_noobj | 0.001389     | 0.000862     |
# +------------+--------------+--------------+
# Total loss 0.8791795969009399
# ---- ETA 0:00:17.249629
#
# ---- [Epoch 16/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.296635     | 0.390666     |
# | x          | 0.005167     | 0.022096     |
# | y          | 0.000860     | 0.004767     |
# | w          | 0.052773     | 0.016797     |
# | h          | 0.017449     | 0.010706     |
# | conf       | 0.213098     | 0.327449     |
# | cls        | 0.007289     | 0.008851     |
# | cls_acc    | 87.50%       | 87.50%       |
# | recall50   | 0.875000     | 0.812500     |
# | recall75   | 0.687500     | 0.750000     |
# | precision  | 0.538462     | 0.270833     |
# | conf_obj   | 0.948716     | 0.876338     |
# | conf_noobj | 0.000866     | 0.000823     |
# +------------+--------------+--------------+
# Total loss 0.6873008012771606
# ---- ETA 0:05:08.485612
#
# ---- [Epoch 16/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 0.443713     | 0.267250     |
# | x          | 0.004321     | 0.013360     |
# | y          | 0.001286     | 0.001529     |
# | w          | 0.006736     | 0.006041     |
# | h          | 0.001753     | 0.006809     |
# | conf       | 0.420786     | 0.228530     |
# | cls        | 0.008829     | 0.010981     |
# | cls_acc    | 81.25%       | 75.00%       |
# | recall50   | 0.812500     | 0.750000     |
# | recall75   | 0.812500     | 0.750000     |
# | precision  | 0.481481     | 0.292683     |
# | conf_obj   | 0.890092     | 0.958151     |
# | conf_noobj | 0.001467     | 0.000949     |
# +------------+--------------+--------------+
# Total loss 0.7109628319740295
# ---- ETA 0:00:49.666596
#
# ---- [Epoch 16/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 0.976062     | 0.682475     |
# | x          | 0.017448     | 0.016015     |
# | y          | 0.001326     | 0.006489     |
# | w          | 0.035616     | 0.018557     |
# | h          | 0.058436     | 0.009568     |
# | conf       | 0.853203     | 0.622856     |
# | cls        | 0.010033     | 0.008990     |
# | cls_acc    | 75.00%       | 81.25%       |
# | recall50   | 0.625000     | 0.812500     |
# | recall75   | 0.562500     | 0.687500     |
# | precision  | 0.555556     | 0.351351     |
# | conf_obj   | 0.800123     | 0.883814     |
# | conf_noobj | 0.001347     | 0.001318     |
# +------------+--------------+--------------+
# Total loss 1.6585376262664795
# ---- ETA 0:00:15.723350
#
# ---- [Epoch 17/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.520595     | 0.478173     |
# | x          | 0.002445     | 0.008567     |
# | y          | 0.001217     | 0.004590     |
# | w          | 0.022415     | 0.013458     |
# | h          | 0.010994     | 0.009967     |
# | conf       | 0.476266     | 0.423323     |
# | cls        | 0.007258     | 0.018267     |
# | cls_acc    | 93.75%       | 62.50%       |
# | recall50   | 0.812500     | 0.562500     |
# | recall75   | 0.750000     | 0.500000     |
# | precision  | 0.541667     | 0.219512     |
# | conf_obj   | 0.879386     | 0.874523     |
# ...
# | x          | 0.004659     | 0.005962     |
# | y          | 0.002259     | 0.001888     |
# | w          | 0.008356     | 0.005355     |
# | h          | 0.005543     | 0.004618     |
# | conf       | 0.377966     | 0.266301     |
# | cls        | 0.004944     | 0.001822     |
# | cls_acc    | 93.75%       | 100.00%      |
# | recall50   | 0.875000     | 0.937500     |
# | recall75   | 0.875000     | 0.937500     |
# | precision  | 0.538462     | 0.405405     |
# | conf_obj   | 0.883830     | 0.910679     |
# | conf_noobj | 0.001225     | 0.000820     |
# +------------+--------------+--------------+
# Total loss 0.6896719932556152
# ---- ETA 0:04:50.017372
# ---- [Epoch 44/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 12           | 24           |
# | loss       | 0.532740     | 0.153917     |
# | x          | 0.007551     | 0.014537     |
# | y          | 0.003292     | 0.001635     |
# | w          | 0.099881     | 0.013643     |
# | h          | 0.225126     | 0.004398     |
# | conf       | 0.190119     | 0.115493     |
# | cls        | 0.006771     | 0.004212     |
# | cls_acc    | 87.50%       | 100.00%      |
# | recall50   | 0.812500     | 1.000000     |
# | recall75   | 0.812500     | 0.941176     |
# | precision  | 0.684211     | 0.680000     |
# | conf_obj   | 0.944842     | 0.973739     |
# | conf_noobj | 0.000693     | 0.000531     |
# +------------+--------------+--------------+
# Total loss 0.6866567134857178
# ---- ETA 0:00:51.445446
#
# ---- [Epoch 44/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 0.270126     | 0.361013     |
# | x          | 0.002014     | 0.014690     |
# | y          | 0.012956     | 0.007236     |
# | w          | 0.021970     | 0.005394     |
# | h          | 0.014439     | 0.003211     |
# | conf       | 0.210562     | 0.319809     |
# | cls        | 0.008185     | 0.010672     |
# | cls_acc    | 87.50%       | 87.50%       |
# | recall50   | 0.812500     | 0.750000     |
# | recall75   | 0.812500     | 0.750000     |
# | precision  | 0.722222     | 0.363636     |
# | conf_obj   | 0.927215     | 0.886447     |
# | conf_noobj | 0.000492     | 0.000609     |
# +------------+--------------+--------------+
# Total loss 0.6311384439468384
# ---- ETA 0:00:17.899249
#
# ---- [Epoch 45/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 0.495072     | 0.521182     |
# | x          | 0.034616     | 0.024480     |
# | y          | 0.001744     | 0.002967     |
# | w          | 0.009603     | 0.006519     |
# | h          | 0.011156     | 0.003086     |
# | conf       | 0.431294     | 0.475818     |
# | cls        | 0.006659     | 0.008311     |
# | cls_acc    | 93.75%       | 81.25%       |
# | recall50   | 0.875000     | 0.750000     |
# | recall75   | 0.875000     | 0.750000     |
# | precision  | 0.823529     | 0.387097     |
# | conf_obj   | 0.933003     | 0.920574     |
# | conf_noobj | 0.000510     | 0.000817     |
# +------------+--------------+--------------+
# Total loss 1.0162540674209595
# ---- ETA 0:04:22.117621
#
# ---- [Epoch 45/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 0.176089     | 0.179113     |
# | x          | 0.002259     | 0.006825     |
# | y          | 0.000901     | 0.001495     |
# | w          | 0.009318     | 0.005855     |
# | h          | 0.005719     | 0.001639     |
# | conf       | 0.155420     | 0.160934     |
# | cls        | 0.002473     | 0.002365     |
# | cls_acc    | 100.00%      | 93.75%       |
# | recall50   | 0.937500     | 0.937500     |
# | recall75   | 0.937500     | 0.937500     |
# | precision  | 0.789474     | 0.576923     |
# | conf_obj   | 0.958142     | 0.960263     |
# | conf_noobj | 0.000621     | 0.000540     |
# +------------+--------------+--------------+
# Total loss 0.35520195960998535
# ---- ETA 0:00:47.163573
#
# ---- [Epoch 45/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 0.416463     | 0.262990     |
# | x          | 0.004489     | 0.010231     |
# | y          | 0.001647     | 0.010857     |
# | w          | 0.009487     | 0.017817     |
# | h          | 0.006645     | 0.007886     |
# | conf       | 0.389570     | 0.210633     |
# | cls        | 0.004626     | 0.005567     |
# | cls_acc    | 93.75%       | 87.50%       |
# | recall50   | 0.812500     | 0.875000     |
# | recall75   | 0.812500     | 0.812500     |
# | precision  | 0.590909     | 0.400000     |
# | conf_obj   | 0.868337     | 0.937859     |
# | conf_noobj | 0.000942     | 0.000720     |
# +------------+--------------+--------------+
# Total loss 0.679452657699585
# ---- ETA 0:00:15.620316
#
# ---- [Epoch 46/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 11           | 22           |
# | loss       | 0.227835     | 0.289698     |
# | x          | 0.007288     | 0.018247     |
# | y          | 0.001270     | 0.001811     |
# | w          | 0.024705     | 0.009953     |
# | h          | 0.039809     | 0.010805     |
# | conf       | 0.146426     | 0.239933     |
# | cls        | 0.008336     | 0.008949     |
# | cls_acc    | 87.50%       | 88.24%       |
# | recall50   | 0.812500     | 0.882353     |
# | recall75   | 0.812500     | 0.823529     |
# | precision  | 0.650000     | 0.441176     |
# | conf_obj   | 0.968212     | 0.931154     |
# | conf_noobj | 0.000647     | 0.000785     |
# +------------+--------------+--------------+
# Total loss 0.5175327062606812
# ---- ETA 0:04:05.945608
#
# ---- [Epoch 46/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 0.659074     | 0.275757     |
# | x          | 0.002374     | 0.002722     |
# | y          | 0.004162     | 0.003392     |
# | w          | 0.092232     | 0.012323     |
# | h          | 0.144221     | 0.002504     |
# | conf       | 0.410345     | 0.247686     |
# | cls        | 0.005740     | 0.007129     |
# | cls_acc    | 93.75%       | 94.12%       |
# | recall50   | 0.750000     | 0.882353     |
# | recall75   | 0.687500     | 0.882353     |
# | precision  | 0.571429     | 0.517241     |
# | conf_obj   | 0.869600     | 0.904160     |
# | conf_noobj | 0.000980     | 0.000631     |
# +------------+--------------+--------------+
# Total loss 0.9348306059837341
# ---- ETA 0:00:50.399274
#
# ---- [Epoch 46/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.378948     | 0.244963     |
# | x          | 0.012211     | 0.015990     |
# | y          | 0.005898     | 0.009847     |
# | w          | 0.006382     | 0.004912     |
# | h          | 0.006306     | 0.002810     |
# | conf       | 0.342277     | 0.206618     |
# | cls        | 0.005875     | 0.004785     |
# | cls_acc    | 81.25%       | 93.75%       |
# | recall50   | 0.750000     | 0.937500     |
# | recall75   | 0.750000     | 0.937500     |
# | precision  | 0.428571     | 0.326087     |
# | conf_obj   | 0.903789     | 0.946202     |
# | conf_noobj | 0.001127     | 0.000717     |
# +------------+--------------+--------------+
# Total loss 0.6239115595817566
# ---- ETA 0:00:15.802304
#
# ---- [Epoch 47/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 0.267061     | 0.208101     |
# | x          | 0.009690     | 0.012012     |
# | y          | 0.000755     | 0.001480     |
# | w          | 0.008477     | 0.005207     |
# | h          | 0.007386     | 0.001994     |
# | conf       | 0.232421     | 0.180601     |
# | cls        | 0.008333     | 0.006808     |
# | cls_acc    | 87.50%       | 87.50%       |
# | recall50   | 0.875000     | 0.875000     |
# | recall75   | 0.812500     | 0.875000     |
# | precision  | 0.608696     | 0.437500     |
# | conf_obj   | 0.933896     | 0.948261     |
# | conf_noobj | 0.000757     | 0.000534     |
# +------------+--------------+--------------+
# Total loss 0.4751620590686798
# ---- ETA 0:04:59.765188
#
# ---- [Epoch 47/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 16           | 32           |
# | loss       | 0.395872     | 0.277142     |
# | x          | 0.008705     | 0.020525     |
# | y          | 0.008996     | 0.004977     |
# | w          | 0.009950     | 0.003358     |
# | h          | 0.019441     | 0.003698     |
# | conf       | 0.345322     | 0.242772     |
# | cls        | 0.003459     | 0.001812     |
# | cls_acc    | 93.75%       | 100.00%      |
# | recall50   | 0.937500     | 1.000000     |
# | recall75   | 0.812500     | 1.000000     |
# | precision  | 0.535714     | 0.313726     |
# | conf_obj   | 0.926808     | 0.964274     |
# | conf_noobj | 0.001316     | 0.001032     |
# +------------+--------------+--------------+
# Total loss 0.6730142831802368
# ---- ETA 0:00:48.693859
# ---- [Epoch 47/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 1.167923     | 0.506357     |
# | x          | 0.016621     | 0.014731     |
# | y          | 0.006282     | 0.006312     |
# | w          | 0.172164     | 0.004589     |
# | h          | 0.374106     | 0.005930     |
# | conf       | 0.594056     | 0.467743     |
# | cls        | 0.004695     | 0.007050     |
# | cls_acc    | 100.00%      | 82.35%       |
# | recall50   | 0.812500     | 0.705882     |
# | recall75   | 0.750000     | 0.705882     |
# | precision  | 0.722222     | 0.428571     |
# | conf_obj   | 0.860623     | 0.846747     |
# | conf_noobj | 0.000679     | 0.000690     |
# +------------+--------------+--------------+
# Total loss 1.674280047416687
# ---- ETA 0:00:15.744818
#
# ---- [Epoch 48/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 0.216732     | 0.276850     |
# | x          | 0.008457     | 0.011227     |
# | y          | 0.025274     | 0.032550     |
# | w          | 0.017491     | 0.009590     |
# | h          | 0.004116     | 0.003631     |
# | conf       | 0.159184     | 0.217959     |
# | cls        | 0.002209     | 0.001894     |
# | cls_acc    | 100.00%      | 100.00%      |
# | recall50   | 0.937500     | 0.937500     |
# | recall75   | 0.875000     | 0.875000     |
# | precision  | 0.882353     | 0.483871     |
# | conf_obj   | 0.937460     | 0.915650     |
# | conf_noobj | 0.000348     | 0.000527     |
# +------------+--------------+--------------+
# Total loss 0.4935818612575531
# ---- ETA 0:04:59.216169
#
# ---- [Epoch 48/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 0.214226     | 0.212722     |
# | x          | 0.007564     | 0.004753     |
# | y          | 0.003882     | 0.001310     |
# | w          | 0.038404     | 0.005645     |
# | h          | 0.079549     | 0.002758     |
# | conf       | 0.077516     | 0.188826     |
# | cls        | 0.007311     | 0.009430     |
# | cls_acc    | 82.35%       | 76.47%       |
# | recall50   | 0.823529     | 0.764706     |
# | recall75   | 0.823529     | 0.764706     |
# | precision  | 0.777778     | 0.448276     |
# | conf_obj   | 0.970249     | 0.930468     |
# | conf_noobj | 0.000168     | 0.000429     |
# +------------+--------------+--------------+
# Total loss 0.426947683095932
# ---- ETA 0:00:52.428577
#
# ---- [Epoch 48/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 14           | 28           |
# | loss       | 0.394087     | 0.321404     |
# | x          | 0.018370     | 0.030252     |
# | y          | 0.002347     | 0.006530     |
# | w          | 0.019989     | 0.015493     |
# | h          | 0.016535     | 0.006127     |
# | conf       | 0.325559     | 0.253281     |
# | cls        | 0.011288     | 0.009721     |
# | cls_acc    | 93.75%       | 87.50%       |
# | recall50   | 0.937500     | 0.875000     |
# | recall75   | 0.750000     | 0.875000     |
# | precision  | 0.625000     | 0.400000     |
# | conf_obj   | 0.930880     | 0.984248     |
# | conf_noobj | 0.001498     | 0.001393     |
# +------------+--------------+--------------+
# Total loss 0.7154914140701294
# ---- ETA 0:00:16.555461
#
# ---- [Epoch 49/50, Batch 0/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 13           | 26           |
# | loss       | 0.076817     | 0.299528     |
# | x          | 0.006122     | 0.003093     |
# | y          | 0.002942     | 0.000818     |
# | w          | 0.014256     | 0.003857     |
# | h          | 0.001844     | 0.002614     |
# | conf       | 0.049798     | 0.287897     |
# | cls        | 0.001855     | 0.001249     |
# | cls_acc    | 100.00%      | 100.00%      |
# | recall50   | 1.000000     | 0.937500     |
# | recall75   | 1.000000     | 0.937500     |
# | precision  | 0.941176     | 0.468750     |
# | conf_obj   | 0.993532     | 0.915694     |
# | conf_noobj | 0.000324     | 0.000676     |
# +------------+--------------+--------------+
# Total loss 0.37634462118148804
# ---- ETA 0:04:34.372828
#
# ---- [Epoch 49/50, Batch 100/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 15           | 30           |
# | loss       | 0.112478     | 0.280587     |
# | x          | 0.009497     | 0.012818     |
# | y          | 0.000792     | 0.001637     |
# | w          | 0.009957     | 0.009917     |
# | h          | 0.016484     | 0.006686     |
# | conf       | 0.072787     | 0.245632     |
# | cls        | 0.002961     | 0.003897     |
# | cls_acc    | 100.00%      | 93.75%       |
# | recall50   | 1.000000     | 0.937500     |
# | recall75   | 0.937500     | 0.937500     |
# | precision  | 0.888889     | 0.340909     |
# | conf_obj   | 0.983775     | 0.940301     |
# | conf_noobj | 0.000305     | 0.000829     |
# +------------+--------------+--------------+
# Total loss 0.39306503534317017
# ---- ETA 0:00:51.262108
#
# ---- [Epoch 49/50, Batch 200/250] ----
# +------------+--------------+--------------+
# | Metrics    | YOLO Layer 0 | YOLO Layer 1 |
# +------------+--------------+--------------+
# | grid_size  | 10           | 20           |
# | loss       | 0.263432     | 0.183685     |
# | x          | 0.002038     | 0.003124     |
# | y          | 0.000514     | 0.001177     |
# | w          | 0.005721     | 0.004067     |
# | h          | 0.008706     | 0.006365     |
# | conf       | 0.245606     | 0.168620     |
# | cls        | 0.000846     | 0.000332     |
# | cls_acc    | 100.00%      | 100.00%      |
# | recall50   | 1.000000     | 1.000000     |
# | recall75   | 1.000000     | 1.000000     |
# | precision  | 0.800000     | 0.592593     |
# | conf_obj   | 0.914151     | 0.969871     |
# | conf_noobj | 0.000995     | 0.000672     |
# +------------+--------------+--------------+
# Total loss 0.447116494178772
# ---- ETA 0:00:16.211707

# %%
def get_image_iteration(myiter):
    return next(myiter)

# %%
labels=[]

# %%
conf_thres = 0.9
nms_thres = 0.9

# %%
def evaluate(b):
    model.eval()
    with torch.no_grad():
        outputs = model(b.to(device))
        outputs = non_max_suppression(outputs, conf_thres=conf_thres, nms_thres=nms_thres)
    return outputs

# %%
from matplotlib.ticker import NullLocator

cmap = plt.get_cmap("tab20b")
colors = [cmap(i) for i in np.linspace(0, 1, 20)]

# %%
def plot_results(index):
    myiter = iter(dataloader)
    a,b,c = get_image_iteration(myiter)
    outputs = evaluate(b)
    # Iterate through images and save plot of detections
    for img_i, (image, detections) in enumerate(zip(b, outputs)):
        print("(%d) Image" % (img_i))

        # Create plot
        #img = np.array(Image.open(path))
        img = image.mul(255).permute(1, 2, 0).byte().cpu().numpy()
        plt.figure()
        fig, ax = plt.subplots(1)
        ax.imshow(img)

        # Draw bounding boxes and labels of detections
        if detections is not None:
            # Rescale boxes to oripginal image
            detections = rescale_boxes(detections, img_size, img.shape[:2])
            unique_labels = detections[:, -1].cpu().unique()
            n_cls_preds = len(unique_labels)
            bbox_colors = random.sample(colors, n_cls_preds)
            for x1, y1, x2, y2, conf, cls_conf, cls_pred in detections:

                print("\t+ Label: %s, Conf: %.5f" % (class_names[int(cls_pred)], cls_conf.item()))

                box_w = x2 - x1
                box_h = y2 - y1

                if cls_conf.item()<0.7:
                    continue



                color = bbox_colors[int(np.where(unique_labels == int(cls_pred))[0])]
                # Create a Rectangle patch
                bbox = patches.Rectangle((x1, y1), box_w, box_h, linewidth=2, edgecolor=color, facecolor="none")
                # Add the bbox to the plot
                ax.add_patch(bbox)
                # Add label
                plt.text(
                    x1,
                    y1,
                    s=class_names[int(cls_pred)]+" {:.1f}".format(cls_conf.item()),
                    color="white",
                    verticalalignment="top",
                    bbox={"color": color, "pad": 0},
                )

        plt.axis("off")
        plt.gca().xaxis.set_major_locator(NullLocator())
        plt.gca().yaxis.set_major_locator(NullLocator())
        plt.savefig("output/example_yolo{}_{}.png".format(str(img_i), str(index)), bbox_inches="tight", pad_inches=0.0,dpi=250)
        plt.show()
        plt.close()

# %%
for j in range(10):
    plot_results(j)
# Out:
# (0) Image
# 	+ Label: ring3, Conf: 0.99698
# 	+ Label: ring3, Conf: 0.99685
# (1) Image
# 	+ Label: ring1, Conf: 0.85136
# 	+ Label: ring2, Conf: 0.63112
# (2) Image
# 	+ Label: ring3, Conf: 0.96951
# 	+ Label: ring3, Conf: 0.93447
# (3) Image
# 	+ Label: ring3, Conf: 0.81210
# 	+ Label: ring3, Conf: 0.79314
# (4) Image
# 	+ Label: ring0, Conf: 0.88315
# 	+ Label: ring0, Conf: 0.81756
# (5) Image
# 	+ Label: ring2, Conf: 0.94965
# 	+ Label: ring2, Conf: 0.94930
# (6) Image
# 	+ Label: ring2, Conf: 0.93801
# 	+ Label: ring2, Conf: 0.71846
# (7) Image
# 	+ Label: ring1, Conf: 0.80381
# 	+ Label: ring1, Conf: 0.79850
# (8) Image
# 	+ Label: ring3, Conf: 0.97897
# 	+ Label: ring3, Conf: 0.91402
# (9) Image
# 	+ Label: ring2, Conf: 0.87351
# 	+ Label: ring1, Conf: 0.75768
# (10) Image
# 	+ Label: ring3, Conf: 0.61763
# 	+ Label: ring3, Conf: 0.42898
# (11) Image
# 	+ Label: ring3, Conf: 0.82190
# 	+ Label: ring3, Conf: 0.73232
# (12) Image
# 	+ Label: ring3, Conf: 0.89578
# 	+ Label: ring3, Conf: 0.63980
# (13) Image
# 	+ Label: ring1, Conf: 0.70402
# (14) Image
# 	+ Label: ring3, Conf: 0.73770
# 	+ Label: ring3, Conf: 0.47852
# (15) Image
# 	+ Label: ring2, Conf: 0.90992
# 	+ Label: ring2, Conf: 0.80476
# (0) Image
# 	+ Label: ring3, Conf: 0.99468
# 	+ Label: ring3, Conf: 0.99207
# (1) Image
# 	+ Label: ring2, Conf: 0.91421
# (2) Image
# 	+ Label: ring3, Conf: 0.92393
# 	+ Label: ring3, Conf: 0.59575
# (3) Image
# 	+ Label: ring2, Conf: 0.98938
# (4) Image
# 	+ Label: ring1, Conf: 0.98580
# (5) Image
# 	+ Label: ring3, Conf: 0.62625
# 	+ Label: ring2, Conf: 0.41812
# (6) Image
# 	+ Label: ring3, Conf: 0.98258
# 	+ Label: ring3, Conf: 0.98880
# (7) Image
# 	+ Label: ring3, Conf: 0.99703
# 	+ Label: ring3, Conf: 0.99572
# (8) Image
# 	+ Label: ring1, Conf: 0.99464
# (9) Image
# 	+ Label: ring2, Conf: 0.99305
# (10) Image
# 	+ Label: ring2, Conf: 0.91397
# (11) Image
# 	+ Label: ring3, Conf: 0.99358
# 	+ Label: ring3, Conf: 0.99935
# (12) Image
# 	+ Label: ring3, Conf: 0.98401
# 	+ Label: ring3, Conf: 0.96906
# 	+ Label: ring3, Conf: 0.97267
# (13) Image
# 	+ Label: ring2, Conf: 0.84958
# 	+ Label: ring2, Conf: 0.57342
# (14) Image
# 	+ Label: ring2, Conf: 0.98278
# 	+ Label: ring2, Conf: 0.98059
# (15) Image
# 	+ Label: ring3, Conf: 0.93689
# 	+ Label: ring3, Conf: 0.95966
# 	+ Label: ring3, Conf: 0.98049
# (0) Image
# 	+ Label: ring3, Conf: 0.99570
# 	+ Label: ring3, Conf: 0.99782
# 	+ Label: ring3, Conf: 0.99915
# (1) Image
# 	+ Label: ring3, Conf: 0.98099
# 	+ Label: ring3, Conf: 0.98900
# 	+ Label: ring3, Conf: 0.97990
# (2) Image
# 	+ Label: ring1, Conf: 0.97095
# 	+ Label: ring1, Conf: 0.70630
# (3) Image
# 	+ Label: ring2, Conf: 0.87268
# 	+ Label: ring2, Conf: 0.84384
# (4) Image
# 	+ Label: ring1, Conf: 0.99897
# 	+ Label: ring1, Conf: 0.91299
# (5) Image
# 	+ Label: ring3, Conf: 0.99925
# 	+ Label: ring3, Conf: 0.99969
# (6) Image
# 	+ Label: ring3, Conf: 0.99611
# (7) Image
# 	+ Label: ring2, Conf: 0.94884
# 	+ Label: ring3, Conf: 0.76581
# (8) Image
# 	+ Label: ring2, Conf: 0.98969
# (9) Image
# 	+ Label: ring3, Conf: 0.99771
# (10) Image
# 	+ Label: ring3, Conf: 0.98641
# 	+ Label: ring3, Conf: 0.99778
# (11) Image
# 	+ Label: ring2, Conf: 0.99251
# (12) Image
# 	+ Label: ring1, Conf: 0.99991
# 	+ Label: ring1, Conf: 0.98120
# (13) Image
# 	+ Label: ring1, Conf: 0.92607
# 	+ Label: ring1, Conf: 0.93393
# 	+ Label: ring1, Conf: 0.87939
# (14) Image
# 	+ Label: ring2, Conf: 0.92129
# 	+ Label: ring1, Conf: 0.60464
# (15) Image
# 	+ Label: ring1, Conf: 0.99200
# 	+ Label: ring1, Conf: 0.78566
# (0) Image
# 	+ Label: ring2, Conf: 0.96401
# 	+ Label: ring2, Conf: 0.95713
# (1) Image
# 	+ Label: ring2, Conf: 0.76848
# 	+ Label: ring2, Conf: 0.74477
# (2) Image
# 	+ Label: ring3, Conf: 0.71375
# 	+ Label: ring3, Conf: 0.54057
# (3) Image
# 	+ Label: ring0, Conf: 0.95442
# 	+ Label: ring0, Conf: 0.97958
# (4) Image
# 	+ Label: ring2, Conf: 0.88125
# 	+ Label: ring2, Conf: 0.75379
# (5) Image
# 	+ Label: ring3, Conf: 0.65583
# 	+ Label: ring3, Conf: 0.53150
# (6) Image
# 	+ Label: ring3, Conf: 0.99314
# 	+ Label: ring3, Conf: 0.99317
# 	+ Label: ring3, Conf: 0.95936
# (7) Image
# 	+ Label: ring1, Conf: 0.99237
# 	+ Label: ring1, Conf: 0.65731
# (8) Image
# 	+ Label: ring3, Conf: 0.71241
# 	+ Label: ring2, Conf: 0.59741
# (9) Image
# 	+ Label: ring2, Conf: 0.94624
# 	+ Label: ring1, Conf: 0.72986
# (10) Image
# 	+ Label: ring1, Conf: 0.97041
# 	+ Label: ring1, Conf: 0.96991
# (11) Image
# 	+ Label: ring2, Conf: 0.97259
# (12) Image
# 	+ Label: ring3, Conf: 0.75606
# 	+ Label: ring3, Conf: 0.38649
# (13) Image
# 	+ Label: ring2, Conf: 0.88798
# 	+ Label: ring2, Conf: 0.84828
# (14) Image
# 	+ Label: ring3, Conf: 0.63544
# 	+ Label: ring3, Conf: 0.58468
# (15) Image
# 	+ Label: ring2, Conf: 0.94850
# (0) Image
# 	+ Label: ring1, Conf: 0.99832
# 	+ Label: ring1, Conf: 0.92097
# (1) Image
# 	+ Label: ring3, Conf: 0.99950
# 	+ Label: ring3, Conf: 0.99916
# (2) Image
# 	+ Label: ring2, Conf: 0.93080
# 	+ Label: ring2, Conf: 0.50891
# (3) Image
# 	+ Label: ring2, Conf: 0.80764
# 	+ Label: ring3, Conf: 0.76865
# (4) Image
# 	+ Label: ring0, Conf: 0.96283
# 	+ Label: ring0, Conf: 0.97741
# (5) Image
# 	+ Label: ring3, Conf: 0.99927
# 	+ Label: ring3, Conf: 0.99936
# (6) Image
# 	+ Label: ring1, Conf: 0.81222
# 	+ Label: ring1, Conf: 0.40340
# (7) Image
# 	+ Label: ring2, Conf: 0.96610
# 	+ Label: ring2, Conf: 0.91600
# (8) Image
# 	+ Label: ring3, Conf: 0.99954
# 	+ Label: ring3, Conf: 0.99861
# (9) Image
# 	+ Label: ring3, Conf: 0.87089
# 	+ Label: ring3, Conf: 0.63289
# (10) Image
# 	+ Label: ring3, Conf: 0.98601
# 	+ Label: ring3, Conf: 0.99642
# (11) Image
# 	+ Label: ring2, Conf: 0.92862
# 	+ Label: ring2, Conf: 0.72093
# (12) Image
# 	+ Label: ring2, Conf: 0.98832
# (13) Image
# 	+ Label: ring3, Conf: 0.99974
# 	+ Label: ring3, Conf: 0.99959
# (14) Image
# (15) Image
# 	+ Label: ring3, Conf: 0.93962
# 	+ Label: ring3, Conf: 0.91919
# (0) Image
# 	+ Label: ring2, Conf: 0.89919
# 	+ Label: ring2, Conf: 0.77911
# (1) Image
# 	+ Label: ring2, Conf: 0.93001
# (2) Image
# 	+ Label: ring2, Conf: 0.83525
# 	+ Label: ring1, Conf: 0.49057
# (3) Image
# (4) Image
# 	+ Label: ring3, Conf: 0.99586
# 	+ Label: ring3, Conf: 0.99269
# (5) Image
# 	+ Label: ring3, Conf: 0.98544
# 	+ Label: ring3, Conf: 0.95194
# (6) Image
# 	+ Label: ring3, Conf: 0.98018
# 	+ Label: ring3, Conf: 0.73243
# (7) Image
# 	+ Label: ring3, Conf: 0.99957
# 	+ Label: ring3, Conf: 0.99889
# (8) Image
# 	+ Label: ring1, Conf: 0.99909
# (9) Image
# 	+ Label: ring1, Conf: 0.98810
# 	+ Label: ring1, Conf: 0.25439
# (10) Image
# 	+ Label: ring3, Conf: 0.89224
# 	+ Label: ring3, Conf: 0.79686
# (11) Image
# 	+ Label: ring3, Conf: 0.82489
# 	+ Label: ring3, Conf: 0.63582
# (12) Image
# 	+ Label: ring1, Conf: 0.99646
# 	+ Label: ring1, Conf: 0.92924

# %%
c
# Out:
# 3
